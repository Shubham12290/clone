# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham12290/clone/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=10
num2=5.5
result=num1+num2
print(result)
# Out:
# 15.5

# %%
a=10
b=5.3
result=b-a
print(result)
# Out:
# -4.7

# %%
bool(0)
# Out:
# False

# %%
a=input()

print(int(a)+int(a))
# Out:
# 15
# 30

# %%
name=input("enter your name")
print(f"{name} i am current pursuing")
# Out:
# enter your nameshubham
# shubham i am current pursuing

# %%
age=(input("nter u age"))
print(f"age is {int(age)+1}")
# Out:
# nter u age15
# age is 16
